# %%
import pandas as pd
import matplotlib.pyplot as mpy
import numpy as np
import pickle

rec=pd.read_csv("Recipes.csv")
mex=pd.read_csv("Mexican_real_real.csv")
ita=pd.read_csv("Italian_real.csv")
rec2=pd.read_fwf("recipes.txt")
from tkinter import *
root=Tk()
root.geometry('500x500')
label1=Label(root,text='Choose which cuisine')
label1.configure(font=(45))
label1.pack()
radio=StringVar()
radio2=StringVar()
m=Message(root)


def indian():
    def selection():
        global selectnv
        selectnv=str(radio.get())
    rb1=Radiobutton(root,text='Crispy Dosas (V)',variable=radio,value='V',command=selection)
    rb1.place(x=600,y=180)
    rb2=Radiobutton(root,text='Chikken Tikka (NV)',variable=radio,value='NV',command=selection)
    rb2.place(x=600,y=240)
    rb3=Radiobutton(root,text='V Fluffy Idlies (V)',variable=radio,value='V1',command=selection)
    rb3.place(x=600,y=300)
    rb4=Radiobutton(root,text='Butter chicken (NV)',variable=radio,value='NV1',command=selection)
    rb4.place(x=600,y=360)
    def open1():
        top=Toplevel(root)
        top.geometry('500x500')
        if selectnv=='V':
            dff=pd.set_option('display.max_colwidth', 1500)
            m=Message(top,text=rec.loc[[0]])
            m.pack()
        elif selectnv=='NV':
            dff=pd.set_option('display.max_colwidth', 1500)
            m=Message(top,text=rec.loc[[2]])
            m.pack()
        elif selectnv=='V1':
            dff=pd.set_option('display.max_colwidth', 1500)
            m=Message(top,text=rec.loc[[1]])
            m.pack()
        elif selectnv=='NV1':
            dff=pd.set_option('display.max_colwidth', 1500)
            m=Message(top,text=rec.loc[[3]])
            m.pack()
        top.mainloop()
    b=Button(root,text='ENTER',command=open1)
    b.place(x=700,y=500)
def mexican():
    def selection():
        global selectnv
        selectnv=str(radio.get())
    rb1=Radiobutton(root,text='7 Layer Burrito (V)',variable=radio,value='V',command=selection) 
    rb1.place(x=600,y=180)
    rb2=Radiobutton(root,text='Chicken taco (NV)',variable=radio,value='NV',command=selection)
    rb2.place(x=600,y=240)
    rb3=Radiobutton(root,text='Chimichanga (V)',variable=radio,value='V1',command=selection) 
    rb3.place(x=600,y=300)
    rb4=Radiobutton(root,text='Chicken Quesidilla (NV)',variable=radio,value='NV1',command=selection) 
    rb4.place(x=600,y=360)
    def open2():
        top=Toplevel(root)
        top.geometry('500x500')
        if selectnv=='V':
            dff=pd.set_option('display.max_colwidth', 1500)
            m=Message(top,text=mex.loc[[0]])
            m.pack()
        elif selectnv=='NV':
            dff=pd.set_option('display.max_colwidth', 1500)
            m=Message(top,text=mex.loc[[2]])
            m.pack()
        elif selectnv=='V1':
            dff=pd.set_option('display.max_colwidth', 1500)
            m=Message(top,text=mex.loc[[1]])
            m.pack()
        elif selectnv=='NV1':
            dff=pd.set_option('display.max_colwidth', 1500)
            m=Message(top,text=mex.loc[[3]])
            m.pack()
        top.mainloop()
    b=Button(root,text='ENTER',command=open2)
    b.place(x=700,y=500)
def italian():
    def selection():
        global selectnv
        selectnv=str(radio.get())
    rb1=Radiobutton(root,text='White Pasta (V)',variable=radio,value='V',command=selection)
    rb1.place(x=600,y=180)
    rb2=Radiobutton(root,text='Cheese Pizza (V)',variable=radio,value='V1',command=selection)
    rb2.place(x=600,y=240)
    rb3=Radiobutton(root,text='Pepperoni Pizza (NV)',variable=radio,value='NV',command=selection)
    rb3.place(x=600,y=300)
    rb4=Radiobutton(root,text='Chicken Pasta (NV)',variable=radio,value='NV1',command=selection)
    rb4.place(x=600,y=360)
    def open2():
        top=Toplevel(root)
        top.geometry('500x500')
        if selectnv=='V':
            dff=pd.set_option('display.max_colwidth', 1500)
            m=Message(top,text=ita.loc[[0]])
            m.pack()
        elif selectnv=='NV':
            dff=pd.set_option('display.max_colwidth', 1500)
            m=Message(top,text=ita.loc[[2]])
            m.pack()
        elif selectnv=='V1':
            dff=pd.set_option('display.max_2colwidth', 1500)
            m=Message(top,text=ita.loc[[1]])
            m.pack()
        elif selectnv=='NV1':
            dff=pd.set_option('display.max_colwidth', 1500)
            m=Message(top,text=ita.loc[[3]])
            m.pack()
        top.mainloop()
    b=Button(root,text='ENTER',command=open2)
    b.place(x=700,y=500)
indian=Button(root,text='INDIAN',command=indian)
indian.place(x=600,y=100)
mexican=Button(root,text='MEXICAN',command=mexican)
mexican.place(x=750,y=100)
italian=Button(root,text='ITALIAN',command=italian)
italian.place(x=900,y=100)



root.mainloop()

# %%
# Out:
#              Dish                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Recipe
# ...
